# %% [markdown]
# # New York City Airbnb Open Data
# #### Airbnb listings and metrics in NYC, NY, USA (2019)
# Airbnb is a paid community platform for renting and booking private accommodation founded in 2008. Airbnb allows individuals to rent all or part of their own home as extra accommodation. The site offers a search and booking platform between the person offering their accommodation and the vacationer who wishes to rent it. It covers more than 1.5 million advertisements in more than 34,000 cities and 191 countries. From creation, inaugust 2008, until June 2012, more than 10 million nights have been booked on Airbnb.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv("../input/new-york-city-airbnb-open-data/AB_NYC_2019.csv")
# df.index.name = None
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df = df.rename(columns={'host_id': 'product_id'})
df
# Out:
#        order_id                                               name  \
# 0          2539                 Clean & quiet apt home by the park
# 1          2595                              Skylit Midtown Castle
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !
# 3          3831                    Cozy Entire Floor of Brownstone
# 4          5022   Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                                ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse
# 48891  36485057      Affordable room in Bushwick/East Williamsburg
# 48892  36485431            Sunny Studio at Historical Neighborhood
# 48893  36485609               43rd St. Time Square-cozy single bed
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen
#
#        product_id      host_name neighbourhood_group       neighbourhood  \
# 0            2787           John            Brooklyn          Kensington
# 1            2845       Jennifer           Manhattan             Midtown
# 2            4632      Elisabeth           Manhattan              Harlem
# 3            4869    LisaRoxanne            Brooklyn        Clinton Hill
# 4            7192          Laura           Manhattan         East Harlem
# ...           ...            ...                 ...                 ...
# 48890     8232441        Sabrina            Brooklyn  Bedford-Stuyvesant
# 48891     6570630        Marisol            Brooklyn            Bushwick
# 48892    23492952  Ilgar & Aysel           Manhattan              Harlem
# 48893    30985759            Taz           Manhattan      Hell's Kitchen
# 48894    68119814     Christophe           Manhattan      Hell's Kitchen
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 0      40.64749  -73.97237     Private room    149               1
# 1      40.75362  -73.98377  Entire home/apt    225               1
# 2      40.80902  -73.94190     Private room    150               3
# 3      40.68514  -73.95976  Entire home/apt     89               1
# 4      40.79851  -73.94399  Entire home/apt     80              10
# ...         ...        ...              ...    ...             ...
# 48890  40.67853  -73.94995     Private room     70               2
# 48891  40.70184  -73.93317     Private room     40               4
# 48892  40.81475  -73.94867  Entire home/apt    115              10
# 48893  40.75751  -73.99112      Shared room     55               1
# 48894  40.76404  -73.98933     Private room     90               7
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      9  2018-10-19               0.21
# 1                     45  2019-05-21               0.38
# 2                      0         NaN                NaN
# 3                    270  2019-07-05               4.64
# 4                      9  2018-11-19               0.10
# ...                  ...         ...                ...
# 48890                  0         NaN                NaN
# 48891                  0         NaN                NaN
# 48892                  0         NaN                NaN
# 48893                  0         NaN                NaN
# 48894                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   6               365
# 1                                   2               355
# 2                                   1               365
# 3                                   1               194
# 4                                   1                 0
# ...                               ...               ...
# 48890                               2                 9
# 48891                               2                36
# 48892                               1                27
# 48893                               6                 2
# 48894                               1                23
#
# [48895 rows x 16 columns]

# %%
df = df.rename(columns={'id': 'order_id'})
df.head()
# Out:
#    order_id                                              name  product_id  \
# 0      2539                Clean & quiet apt home by the park        2787
# 1      2595                             Skylit Midtown Castle        2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !        4632
# 3      3831                   Cozy Entire Floor of Brownstone        4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park        7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df = df.rename(columns={'minimum_nights': 'add_to_cart_order'})
df.head()
# Out:
#    order_id                                              name  product_id  \
# 0      2539                Clean & quiet apt home by the park        2787
# 1      2595                             Skylit Midtown Castle        2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !        4632
# 3      3831                   Cozy Entire Floor of Brownstone        4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park        7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  add_to_cart_order  number_of_reviews last_review  \
# 0     Private room    149                  1                  9  2018-10-19
# 1  Entire home/apt    225                  1                 45  2019-05-21
# 2     Private room    150                  3                  0         NaN
# 3  Entire home/apt     89                  1                270  2019-07-05
# 4  Entire home/apt     80                 10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df = df.rename(columns={'number_of_reviews': 'reordered'})
df.head()
# Out:
#    order_id                                              name  product_id  \
# 0      2539                Clean & quiet apt home by the park        2787
# 1      2595                             Skylit Midtown Castle        2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !        4632
# 3      3831                   Cozy Entire Floor of Brownstone        4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park        7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  add_to_cart_order  reordered last_review  \
# 0     Private room    149                  1          9  2018-10-19
# 1  Entire home/apt    225                  1         45  2019-05-21
# 2     Private room    150                  3          0         NaN
# 3  Entire home/apt     89                  1        270  2019-07-05
# 4  Entire home/apt     80                 10          9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
#每個使用者的購物紀錄
df1 = df[['order_id','product_id','add_to_cart_order','reordered']]
orders=df1
articles = orders
articles
# Out:
#        order_id  product_id  add_to_cart_order  reordered
# 0          2539        2787                  1          9
# 1          2595        2845                  1         45
# 2          3647        4632                  3          0
# 3          3831        4869                  1        270
# 4          5022        7192                 10          9
# ...         ...         ...                ...        ...
# 48890  36484665     8232441                  2          0
# 48891  36485057     6570630                  4          0
# 48892  36485431    23492952                 10          0
# 48893  36485609    30985759                  1          0
# 48894  36487245    68119814                  7          0
#
# [48895 rows x 4 columns]

# %%
aisles1 = pd.read_csv("../input/new-york-city-airbnb-open-data/AB_NYC_2019.csv")
aisles1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
aisles = aisles1[['host_id', 'host_name',]]
aisles = aisles.rename(columns={'host_id': 'order_id','host_name': 'aisle_name'})
aisles
# Out:
#        order_id     aisle_name
# 0          2787           John
# 1          2845       Jennifer
# 2          4632      Elisabeth
# 3          4869    LisaRoxanne
# 4          7192          Laura
# ...         ...            ...
# 48890   8232441        Sabrina
# 48891   6570630        Marisol
# 48892  23492952  Ilgar & Aysel
# 48893  30985759            Taz
# 48894  68119814     Christophe
#
# [48895 rows x 2 columns]

# %%
_mt = pd.merge(df,orders, on = ['product_id','product_id'])
_mt = _mt.rename(columns={'order_id_x': 'order_id','add_to_cart_order_x': 'add_to_cart_order','reordered_x': 'reordered'})
_mt.head(2)
# Out:
#    order_id                                name  product_id host_name  \
# 0      2539  Clean & quiet apt home by the park        2787      John
# 1      2539  Clean & quiet apt home by the park        2787      John
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0            Brooklyn    Kensington  40.64749  -73.97237  Private room    149
# 1            Brooklyn    Kensington  40.64749  -73.97237  Private room    149
#
#    add_to_cart_order  reordered last_review  reviews_per_month  \
# 0                  1          9  2018-10-19               0.21
# 1                  1          9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365  order_id_y  \
# 0                               6               365        2539
# 1                               6               365     7937553
#
#    add_to_cart_order_y  reordered_y
# 0                    1            9
# 1                    1           21

# %%
_mt = pd.merge(_mt,orders,on=['order_id','order_id'])
_mt.head(3)
# Out:
#    order_id                                name  product_id_x host_name  \
# 0      2539  Clean & quiet apt home by the park          2787      John
# 1      2539  Clean & quiet apt home by the park          2787      John
# 2      2539  Clean & quiet apt home by the park          2787      John
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0            Brooklyn    Kensington  40.64749  -73.97237  Private room    149
# 1            Brooklyn    Kensington  40.64749  -73.97237  Private room    149
# 2            Brooklyn    Kensington  40.64749  -73.97237  Private room    149
#
#    ...  last_review  reviews_per_month calculated_host_listings_count  \
# 0  ...   2018-10-19               0.21                              6
# 1  ...   2018-10-19               0.21                              6
# 2  ...   2018-10-19               0.21                              6
#
#    availability_365  order_id_y  add_to_cart_order_y  reordered_y  \
# 0               365        2539                    1            9
# 1               365     7937553                    1           21
# 2               365    10160215                    1           17
#
#    product_id_y  add_to_cart_order_y  reordered_y
# 0          2787                    1            9
# 1          2787                    1            9
# 2          2787                    1            9
#
# [3 rows x 22 columns]

# %%
mt = pd.merge(_mt,aisles,on=['order_id','order_id'])
mt.head(3)
# Out:
#    order_id                                 name  product_id_x  host_name  \
# 0      3647  THE VILLAGE OF HARLEM....NEW YORK !          4632  Elisabeth
# 1      3647  THE VILLAGE OF HARLEM....NEW YORK !          4632  Elisabeth
# 2      7322                      Chelsea Perfect         18946       Doti
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0           Manhattan        Harlem  40.80902  -73.94190  Private room    150
# 1           Manhattan        Harlem  40.80902  -73.94190  Private room    150
# 2           Manhattan       Chelsea  40.74192  -73.99501  Private room    140
#
#    ...  reviews_per_month  calculated_host_listings_count availability_365  \
# 0  ...                NaN                               1              365
# 1  ...                NaN                               1              365
# 2  ...               2.12                               1               12
#
#    order_id_y  add_to_cart_order_y  reordered_y  product_id_y  \
# 0        3647                    3            0          4632
# 1        3647                    3            0          4632
# 2        7322                    1          260         18946
#
#    add_to_cart_order_y  reordered_y  aisle_name
# 0                    3            0      Rafael
# 1                    3            0      Rafael
# 2                    1          260       Chris
#
# [3 rows x 23 columns]

# %%
mt = mt.rename(columns={'order_id': 't_dat','order_id_y': 'customer_id', 'product_id_x': 'article_id', 'add_to_cart_order_y': 'frequency'})
GraphTravel_HM = mt
GraphTravel_HM = GraphTravel_HM[['t_dat','customer_id','article_id','frequency']] 
GraphTravel_HM
# Out:
#         t_dat  customer_id  article_id  frequency  frequency
# 0        3647         3647        4632          3          3
# 1        3647         3647        4632          3          3
# 2        7322         7322       18946          1          1
# 3       31994        31994      137814          2          2
# 4       31994        42580      137814          2          2
# ..        ...          ...         ...        ...        ...
# 178  29941633     29941633     3218399         10         10
# 179  31929849     31929849     7958766          2          2
# 180  33945670     33945670    43332874          7          7
# 181  33945670     33945670    43332874          7          7
# 182  35914632     35914632   269987340          3          3
#
# [183 rows x 5 columns]

# %%
sns.distplot(GraphTravel_HM['frequency'], kde=True, bins=30)

plt.title('Distribution of frequency')
plt.xlabel('Frequency')
plt.ylabel('Density')

plt.show()
# Out:
# /tmp/ipykernel_24/521335795.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(GraphTravel_HM['frequency'], kde=True, bins=30)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#產品的名稱跟哪一個銷售區域
products = pd.read_csv("../input/new-york-city-airbnb-open-data/AB_NYC_2019.csv")
articles = products
articles.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365

# %%
articles = articles.rename(columns={'host_id': 'article_id','host_name': 'product_name'})
articles.head()
# Out:
#      id                                              name  article_id  \
# 0  2539                Clean & quiet apt home by the park        2787
# 1  2595                             Skylit Midtown Castle        2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !        4632
# 3  3831                   Cozy Entire Floor of Brownstone        4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park        7192
#
#   product_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
def get_rated_items(user_id, df):
    return set(df[df['customer_id'] == user_id]['article_id'])

# %%
# Random Walk # generate_walks(G, 2, 8, p=0.5, q=0.5)
walks = generate_walks(G, 2, 8, p=0.5, q=0.5)
filtered_walks = [walk for walk in walks if len(walk) >= 5]

# to String  (for Word2Vec input)
walks = [[str(node) for node in walk] for walk in walks]

# Word2Vec train
model = Word2Vec(walks, vector_size=128, window=5, min_count=0,  hs=1, sg=1, workers=4, epochs=10)

# node embedding extract
embeddings = {node_id: model.wv[node_id] for node_id in model.wv.index_to_key}

# %%
# biased random walk  
def biased_random_walk(G, start_node, walk_length, p=1, q=1):
    walk = [start_node]

    while len(walk) < walk_length:
        cur_node = walk[-1]
        cur_neighbors = list(G.neighbors(cur_node))

        if len(cur_neighbors) > 0:
            if len(walk) == 1:
                walk.append(random.choice(cur_neighbors))
            else:
                prev_node = walk[-2]

                probability = []
                for neighbor in cur_neighbors:
                    if neighbor == prev_node:
                        # Return parameter 
                        probability.append(1/p)
                    elif G.has_edge(neighbor, prev_node):
                        # Stay parameter 
                        probability.append(1)
                    else:
                        # In-out parameter 
                        probability.append(1/q)

                probability = np.array(probability)
                probability = probability / probability.sum()  # normalize

                next_node = np.random.choice(cur_neighbors, p=probability)
                walk.append(next_node)
        else:
            break

    return walk

# %%
G = nx.Graph()

for index, row in GraphTravel_HM.iterrows():
    G.add_node(row['customer_id'], type='user')
    G.add_node(row['article_id'], type='item')
    G.add_edge(row['customer_id'], row['article_id'], weight=row['frequency'])

# %%
def generate_walks(G, num_walks, walk_length, p=1, q=1):
    walks = []
    nodes = list(G.nodes())
    for _ in range(num_walks):
        random.shuffle(nodes)  # to ensure randomness
        for node in nodes:
            walk_from_node = biased_random_walk(G, node, walk_length, p, q)
            walks.append(walk_from_node)
    return walks

# %%
unique_customer_ids = GraphTravel_HM['customer_id'].unique()
customer_id_mapping = {id: i for i, id in enumerate(unique_customer_ids)}
GraphTravel_HM['customer_id'] = GraphTravel_HM['customer_id'].map(customer_id_mapping)
item_name_mapping = dict(zip(articles['article_id'], articles['product_name'])) # prod_name
# Out:
# /tmp/ipykernel_24/4090393013.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GraphTravel_HM['customer_id'] = GraphTravel_HM['customer_id'].map(customer_id_mapping)

# %%
def get_rated_items(user_id, df):
    return set(df[df['customer_id'] == user_id]['article_id'])

# %%
def get_user_embedding(user_id, embeddings):
    return embeddings[str(user_id)]

# %%
def calculate_similarities(user_id, df, embeddings):
    rated_items = get_rated_items(user_id, df)
    user_embedding = get_user_embedding(user_id, embeddings)

    item_similarities = []
    for item_id in set(df['article_id']):
        if item_id not in rated_items:  
            item_embedding = embeddings[str(item_id)]
            similarity = cosine_similarity([user_embedding], [item_embedding])[0][0]
            item_similarities.append((item_id, similarity))

    return item_similarities

# %%
def recommend_items(user_id, df, embeddings, item_name_mapping, num_items=5):
    rated_items = get_rated_items(user_id, df)
    
    print(f"User {user_id} has purchased:")
    show_images([(item_id, 0) for item_id in list(rated_items)[:5]], item_name_mapping, min(len(rated_items), 5))
    
    item_similarities = calculate_similarities(user_id, df, embeddings)

    recommended_items = sorted(item_similarities, key=lambda x: x[1], reverse=True)[:num_items]

    print(f"\nRecommended items for user {user_id}:")
    show_images(recommended_items, item_name_mapping, num_items, show_similarity=True)

# %%
# costomer 45's top 5  
recommend_items( 45, GraphTravel_HM, embeddings, item_name_mapping, num_items=5)
# Out:
# User 45 has purchased:
#
# Recommended items for user 45:
# - Item 4632: Elisabeth with similarity score: 0.6664034724235535
# Image for item 4632 not found.
# - Item 38204730: Kathy with similarity score: 0.656387448310852
# Image for item 38204730 not found.
# - Item 12485770: Raanan with similarity score: 0.6353153586387634
# Image for item 12485770 not found.
# - Item 160495098: Miller with similarity score: 0.6127380132675171
# Image for item 160495098 not found.
# - Item 69545272: Ben with similarity score: 0.6115382313728333
# Image for item 69545272 not found.

# %%
# costomer 45's top 5  
recommend_items( 100, GraphTravel_HM, embeddings, item_name_mapping, num_items=5)
# Out:
# User 100 has purchased:
#
# Recommended items for user 100:
# - Item 161268152: Maytal And Ken with similarity score: 0.872789740562439
# Image for item 161268152 not found.
# - Item 7360975: Calvin with similarity score: 0.8194672465324402
# Image for item 7360975 not found.
# - Item 1675255: Jill with similarity score: 0.7791862487792969
# Image for item 1675255 not found.
# - Item 1349340: Noah with similarity score: 0.7336462140083313
# Image for item 1349340 not found.
# - Item 26079021: Michael with similarity score: 0.6948009729385376
# Image for item 26079021 not found.

# %%
# costomer 45's top 5  
recommend_items( 50, GraphTravel_HM, embeddings, item_name_mapping, num_items=5)
# Out:
# User 50 has purchased:
#
# Recommended items for user 50:
# - Item 269987340: Nicolas with similarity score: 0.8614672422409058
# Image for item 269987340 not found.
# - Item 144197377: Riley with similarity score: 0.8176286220550537
# Image for item 144197377 not found.
# - Item 3000089: Kimberly with similarity score: 0.8072959184646606
# Image for item 3000089 not found.
# - Item 19285185: Joel with similarity score: 0.7488809823989868
# Image for item 19285185 not found.
# - Item 7815949: Dee with similarity score: 0.6601086854934692
# Image for item 7815949 not found.

# %%
# costomer 45's top 5  
recommend_items( 10, GraphTravel_HM, embeddings, item_name_mapping, num_items=5)
# Out:
# User 10 has purchased:
#
# Recommended items for user 10:
# - Item 160495098: Miller with similarity score: 0.7792606353759766
# Image for item 160495098 not found.
# - Item 69545272: Ben with similarity score: 0.6935999393463135
# Image for item 69545272 not found.
# - Item 2979607: Miriam with similarity score: 0.6602954864501953
# Image for item 2979607 not found.
# - Item 12485770: Raanan with similarity score: 0.6590560674667358
# Image for item 12485770 not found.
# - Item 49964890: Hanson with similarity score: 0.617601752281189
# Image for item 49964890 not found.

# %%
# costomer 45's top 5  
recommend_items( 20, GraphTravel_HM, embeddings, item_name_mapping, num_items=20)
# Out:
# User 20 has purchased:
#
# Recommended items for user 20:
# - Item 69545272: Ben with similarity score: 0.8407365083694458
# Image for item 69545272 not found.
# - Item 12485770: Raanan with similarity score: 0.8302960991859436
# Image for item 12485770 not found.
# - Item 137814: Waldemar with similarity score: 0.8083434104919434
# Image for item 137814 not found.
# - Item 12798614: Jessica with similarity score: 0.7719731330871582
# Image for item 12798614 not found.
# - Item 160495098: Miller with similarity score: 0.7306702733039856
# Image for item 160495098 not found.
# - Item 2979607: Miriam with similarity score: 0.6680232286453247
# Image for item 2979607 not found.
# - Item 119523037: Anna with similarity score: 0.6530411243438721
# Image for item 119523037 not found.
# - Item 295128: Carol Gloria with similarity score: 0.5959587693214417
# Image for item 295128 not found.
# - Item 9820942: Erica And Jorel with similarity score: 0.5793652534484863
# Image for item 9820942 not found.
# - Item 12879538: Gregory with similarity score: 0.5666768550872803
# Image for item 12879538 not found.
# - Item 18946: Doti with similarity score: 0.4900018870830536
# Image for item 18946 not found.
# - Item 161268152: Maytal And Ken with similarity score: 0.4857133626937866
# Image for item 161268152 not found.
# - Item 1289635: Alan with similarity score: 0.47438645362854004
# Image for item 1289635 not found.
# - Item 1349340: Noah with similarity score: 0.45737096667289734
# Image for item 1349340 not found.
# - Item 14061862: Jay with similarity score: 0.43685564398765564
# Image for item 14061862 not found.
# - Item 5309160: Elizabeth And Roberto with similarity score: 0.4303118586540222
# Image for item 5309160 not found.
# - Item 19285185: Joel with similarity score: 0.41470056772232056
# Image for item 19285185 not found.
# - Item 38204730: Kathy with similarity score: 0.4091659188270569
# Image for item 38204730 not found.
# - Item 66513544: Michele with similarity score: 0.3897312879562378
# Image for item 66513544 not found.
# - Item 4632: Elisabeth with similarity score: 0.3448615074157715
# Image for item 4632 not found.

# %%
def show_images(items, item_name_mapping, num_items, show_similarity=False):
    f, ax = plt.subplots(1, num_items, figsize=(20,10))
    if num_items == 1:
        ax = [ax]
    for i, item in enumerate(items):
        item_id, similarity = item
        print(f"- Item {item_id}: {item_name_mapping[item_id]}", end='')
        if show_similarity:
            print(f" with similarity score: {similarity}")
        else:
            print()
        img_path = f"../input/h-and-m-personalized-fashion-recommendations/images/085/0850792002.jpg"
        try:
            img = mpimg.imread(img_path)
            ax[i].imshow(img)
            ax[i].set_title(f'Item {item_id}')
            ax[i].set_xticks([], [])
            ax[i].set_yticks([], [])
            ax[i].grid(False)
        except FileNotFoundError:
            print(f"Image for item {item_id} not found.")
    plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import networkx as nx
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.image as mpimg
import random
